# %%
import numpy as np
import pandas as pd

from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
#from sklearn.preprocessing import KBinsDiscretizer
from matplotlib.pyplot import figure

# Read CSV file and import the data as DataFrame
filename = "E:\\Work\\FinalProjectData\\record_second.csv"
names = ['name', 'address', 'phoneNumber', 'region','age', 'callCount', 'activeCallTime', 
         'smsCount', 'dataUsage', 'Subscription_1', 'Subscription_2', 
         'Subscription_3', 'Subscription_4', 'plan']
dataset = pd.read_csv(filename, names=names)

# The below values are scrapped since they do not contribute to the prediction
dataset.pop('name')
dataset.pop('address')
dataset.pop('phoneNumber')

#print(dataset.describe())
#print(dataset.groupby('plan').size())
        
# To convert the string to number. Here city names are converted to integer.
le = LabelEncoder()
for col in dataset.columns:
    
    if col == 'region':
        dataset[col] = LabelEncoder().fit_transform(dataset[col])

print(dataset)

array = dataset.values
x = array[:,0:9]
y = array[:,10]

# Splitting the dataset into training and test set.  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)  

from sklearn.ensemble import RandomForestClassifier  
classifier= RandomForestClassifier(n_estimators= 100, criterion="entropy")  
classifier.fit(x_train, y_train)



'''
low_limit = 0
upper_limit = 1
for i in range(20):
    y_pred= classifier.predict(x_test[low_limit:upper_limit])
    #print(y_pred)
    if(y_pred != y_test[low_limit:upper_limit]):
        print("upper_limit: ", upper_limit, y_pred)
       
    low_limit = low_limit + 1
    upper_limit = upper_limit + 1
'''

# Read CSV file and import the data as DataFrame
file_actual = "E:\\Work\\FinalProjectData\\record_actual_data.csv"
dataset_actual = pd.read_csv(file_actual, names=names)

# The below values are scrapped since they do not contribute to the prediction
dataset_actual.pop('name')
dataset_actual.pop('address')
dataset_actual.pop('phoneNumber')

#print(dataset.describe())
#print(dataset.groupby('plan').size())
        
# To convert the string to number. Here city names are converted to integer.
for col in dataset_actual.columns:
    if col == 'region':
        dataset_actual[col] = LabelEncoder().fit_transform(dataset_actual[col])

array_actual = dataset_actual.values
x_actual = array_actual[:,0:9]
y_actual = array_actual[:,10]

y_pred= classifier.predict(x_actual)

for i in range(0, len(x_actual)):
    if y_actual[i] != y_pred[i]:
        print("Record: ", i+1, " is not in correct plan. Predicted Plan: ", y_pred[i])
# Out:
# Record:  132  is not in correct plan. Predicted Plan:  2
# Record:  206  is not in correct plan. Predicted Plan:  1
# Record:  211  is not in correct plan. Predicted Plan:  1
# Record:  213  is not in correct plan. Predicted Plan:  1
# Record:  243  is not in correct plan. Predicted Plan:  1
# Record:  252  is not in correct plan. Predicted Plan:  1
# Record:  257  is not in correct plan. Predicted Plan:  1
# Record:  259  is not in correct plan. Predicted Plan:  1
# Record:  263  is not in correct plan. Predicted Plan:  1
# Record:  268  is not in correct plan. Predicted Plan:  1
# Record:  290  is not in correct plan. Predicted Plan:  1
# Record:  307  is not in correct plan. Predicted Plan:  1
# Record:  311  is not in correct plan. Predicted Plan:  1
# Record:  313  is not in correct plan. Predicted Plan:  1
# Record:  323  is not in correct plan. Predicted Plan:  1
# Record:  332  is not in correct plan. Predicted Plan:  1
# Record:  340  is not in correct plan. Predicted Plan:  1
# Record:  344  is not in correct plan. Predicted Plan:  1
# Record:  363  is not in correct plan. Predicted Plan:  1
# Record:  415  is not in correct plan. Predicted Plan:  1
# Record:  442  is not in correct plan. Predicted Plan:  1
# Record:  449  is not in correct plan. Predicted Plan:  1
# Record:  457  is not in correct plan. Predicted Plan:  1
# Record:  470  is not in correct plan. Predicted Plan:  1
# Record:  487  is not in correct plan. Predicted Plan:  1
# Record:  498  is not in correct plan. Predicted Plan:  1
# Record:  519  is not in correct plan. Predicted Plan:  2
# Record:  558  is not in correct plan. Predicted Plan:  4
# Record:  624  is not in correct plan. Predicted Plan:  4
# Record:  701  is not in correct plan. Predicted Plan:  4
# Record:  832  is not in correct plan. Predicted Plan:  4
# Record:  951  is not in correct plan. Predicted Plan:  3
# Record:  960  is not in correct plan. Predicted Plan:  3
# Record:  965  is not in correct plan. Predicted Plan:  3
# Record:  971  is not in correct plan. Predicted Plan:  3
# Record:  972  is not in correct plan. Predicted Plan:  3
# Record:  997  is not in correct plan. Predicted Plan:  3
# Record:  1006  is not in correct plan. Predicted Plan:  3
# Record:  1015  is not in correct plan. Predicted Plan:  3
# Record:  1017  is not in correct plan. Predicted Plan:  3
# Record:  1018  is not in correct plan. Predicted Plan:  3
# Record:  1029  is not in correct plan. Predicted Plan:  3
# Record:  1035  is not in correct plan. Predicted Plan:  3
# Record:  1045  is not in correct plan. Predicted Plan:  3
# Record:  1051  is not in correct plan. Predicted Plan:  3
# Record:  1053  is not in correct plan. Predicted Plan:  3
# Record:  1065  is not in correct plan. Predicted Plan:  3
# Record:  1070  is not in correct plan. Predicted Plan:  3
# Record:  1087  is not in correct plan. Predicted Plan:  3
# Record:  1108  is not in correct plan. Predicted Plan:  3
# Record:  1113  is not in correct plan. Predicted Plan:  3
# Record:  1121  is not in correct plan. Predicted Plan:  3
# Record:  1161  is not in correct plan. Predicted Plan:  3
# Record:  1164  is not in correct plan. Predicted Plan:  3
# Record:  1171  is not in correct plan. Predicted Plan:  3
# Record:  1174  is not in correct plan. Predicted Plan:  3
# Record:  1197  is not in correct plan. Predicted Plan:  3
# Record:  1206  is not in correct plan. Predicted Plan:  3
# Record:  1210  is not in correct plan. Predicted Plan:  3
# Record:  1224  is not in correct plan. Predicted Plan:  3
# Record:  1233  is not in correct plan. Predicted Plan:  3
# Record:  1235  is not in correct plan. Predicted Plan:  3
# Record:  1241  is not in correct plan. Predicted Plan:  3
# Record:  1244  is not in correct plan. Predicted Plan:  3
# Record:  1246  is not in correct plan. Predicted Plan:  3
# Record:  1253  is not in correct plan. Predicted Plan:  3
# Record:  1264  is not in correct plan. Predicted Plan:  3
# Record:  1271  is not in correct plan. Predicted Plan:  3
# Record:  1283  is not in correct plan. Predicted Plan:  3
# Record:  1285  is not in correct plan. Predicted Plan:  3
# Record:  1300  is not in correct plan. Predicted Plan:  3
# Record:  1307  is not in correct plan. Predicted Plan:  3
# Record:  1317  is not in correct plan. Predicted Plan:  3
# Record:  1327  is not in correct plan. Predicted Plan:  3
# Record:  1333  is not in correct plan. Predicted Plan:  3
# Record:  1338  is not in correct plan. Predicted Plan:  3
# Record:  1349  is not in correct plan. Predicted Plan:  3
# Record:  1395  is not in correct plan. Predicted Plan:  3
# Record:  1400  is not in correct plan. Predicted Plan:  3
# Record:  1404  is not in correct plan. Predicted Plan:  3
# Record:  1423  is not in correct plan. Predicted Plan:  3
# Record:  1430  is not in correct plan. Predicted Plan:  3
# Record:  1434  is not in correct plan. Predicted Plan:  3
# Record:  1437  is not in correct plan. Predicted Plan:  3
# Record:  1438  is not in correct plan. Predicted Plan:  3
# Record:  1446  is not in correct plan. Predicted Plan:  3
# Record:  1450  is not in correct plan. Predicted Plan:  3
# Record:  1476  is not in correct plan. Predicted Plan:  3
# Record:  1483  is not in correct plan. Predicted Plan:  3
# Record:  1492  is not in correct plan. Predicted Plan:  3
# Record:  1493  is not in correct plan. Predicted Plan:  3
# Record:  1498  is not in correct plan. Predicted Plan:  3
# Record:  1499  is not in correct plan. Predicted Plan:  3
# Record:  1507  is not in correct plan. Predicted Plan:  4
# Record:  1528  is not in correct plan. Predicted Plan:  4
# Record:  1530  is not in correct plan. Predicted Plan:  4
# Record:  1531  is not in correct plan. Predicted Plan:  4
# Record:  1544  is not in correct plan. Predicted Plan:  4
# Record:  1562  is not in correct plan. Predicted Plan:  4
# Record:  1563  is not in correct plan. Predicted Plan:  4
# Record:  1569  is not in correct plan. Predicted Plan:  4
# Record:  1588  is not in correct plan. Predicted Plan:  4
# Record:  1605  is not in correct plan. Predicted Plan:  4
# Record:  1628  is not in correct plan. Predicted Plan:  4
# Record:  1630  is not in correct plan. Predicted Plan:  4
# Record:  1654  is not in correct plan. Predicted Plan:  4
# Record:  1656  is not in correct plan. Predicted Plan:  4
# Record:  1669  is not in correct plan. Predicted Plan:  4
# Record:  1670  is not in correct plan. Predicted Plan:  4
# Record:  1673  is not in correct plan. Predicted Plan:  4
# Record:  1709  is not in correct plan. Predicted Plan:  4
# Record:  1728  is not in correct plan. Predicted Plan:  4
# Record:  1750  is not in correct plan. Predicted Plan:  4
# Record:  1759  is not in correct plan. Predicted Plan:  4
# Record:  1761  is not in correct plan. Predicted Plan:  4
# Record:  1781  is not in correct plan. Predicted Plan:  4
# Record:  1783  is not in correct plan. Predicted Plan:  4
# Record:  1786  is not in correct plan. Predicted Plan:  4
# Record:  1798  is not in correct plan. Predicted Plan:  4
# Record:  1799  is not in correct plan. Predicted Plan:  4
# Record:  1801  is not in correct plan. Predicted Plan:  5
# Record:  1835  is not in correct plan. Predicted Plan:  5
# Record:  1856  is not in correct plan. Predicted Plan:  5
# Record:  1937  is not in correct plan. Predicted Plan:  5
# Record:  1945  is not in correct plan. Predicted Plan:  6
# Record:  1954  is not in correct plan. Predicted Plan:  6
# Record:  1958  is not in correct plan. Predicted Plan:  6
# Record:  1970  is not in correct plan. Predicted Plan:  6
# Record:  1981  is not in correct plan. Predicted Plan:  6
# Record:  1985  is not in correct plan. Predicted Plan:  6
